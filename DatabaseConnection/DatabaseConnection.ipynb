# %%
# import dependencies
from config import db_password
import pandas as pd
import numpy as np
import psycopg2

# %%
# Create connection string
connection = psycopg2.connect(
    host="db-teampythonkmj.cpwllxwxyx60.us-east-2.rds.amazonaws.com",
    database="Materials",
    user="TeamPythonKMJ",
    password=db_password)

# %%
# create cursor
cursor = connection.cursor()
# Perform SQL query
cursor.execute('SELECT * FROM "Materials_Properties"')
formula = cursor.fetchall() 
# Print SQL query
print("Print each row and select column values")
for row in formula:
    print("mp_id = ", row[0])
    print("Formula = ", row[1])
    print("Y_Modulus  = ", row[9])
# Out:
# Print each row and select column values
# mp_id =  mp-1021323
# Formula =  LiC12
# Y_Modulus  =  233.24
# mp_id =  mp-1021328
# Formula =  H4C
# Y_Modulus  =  0.0
# mp_id =  mp-10721
# Formula =  Ti2C
# Y_Modulus  =  196.56
# mp_id =  mp-1086
# Formula =  TaC
# Y_Modulus  =  528.9
# mp_id =  mp-1164
# Formula =  ThC
# Y_Modulus  =  186.88
# mp_id =  mp-11714
# Formula =  SiC
# Y_Modulus  =  433.84
# mp_id =  mp-12574
# Formula =  Dy2C
# Y_Modulus  =  77.4
# mp_id =  mp-1334
# Formula =  Y2C
# Y_Modulus  =  81.92
# mp_id =  mp-15178
# Formula =  Lu4C7
# Y_Modulus  =  187.5
# mp_id =  mp-1552
# Formula =  Mo2C
# Y_Modulus  =  384.0
# mp_id =  mp-1569
# Formula =  Be2C
# Y_Modulus  =  498.96
# mp_id =  mp-1591
# Formula =  Al4C3
# Y_Modulus  =  273.46
# mp_id =  mp-1894
# Formula =  WC
# Y_Modulus  =  675.18
# mp_id =  mp-20066
# Formula =  CO2
# Y_Modulus  =  7.62
# mp_id =  mp-20181
# Formula =  Ce2C3
# Y_Modulus  =  175.0
# mp_id =  mp-20648
# Formula =  V2C
# Y_Modulus  =  301.86
# ...
