# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('../All Data Export/Ti_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/C_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Cr_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Fe_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Hf_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Mo_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Nb_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Ni_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/V_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/W_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Zr_compounds_dataframe.csv'))
# df = pd.read_csv(Path('../All Data Export/Ta_compounds_dataframe.csv'))

df.head()
# Out:
#    Unnamed: 0       mp_id Formula             Composition       IPF  \
# 0           0  mp-1014229   Ti2Zn  {'Ti': 2.0, 'Zn': 1.0}  0.163919
# 1           1  mp-1014230    TiZn  {'Ti': 1.0, 'Zn': 1.0}  0.174651
# 2           2  mp-1017985    TiAg  {'Ti': 1.0, 'Ag': 1.0}  0.226014
# 3           3  mp-1018028     TiS   {'Ti': 1.0, 'S': 1.0}  0.182130
# 4           4  mp-1018123   TiAu2  {'Ti': 1.0, 'Au': 2.0}  0.248079
#
#      Density                                     Elastic_Tensor  E_above_Hull  \
# 0   5.462442  {'G_Reuss': 29.0, 'G_VRH': 47.0, 'G_Voigt': 65...           0.0
# 1   6.036543  {'G_Reuss': 44.0, 'G_VRH': 56.0, 'G_Voigt': 69...           0.0
# 2   7.340359  {'G_Reuss': 32.0, 'G_VRH': 35.0, 'G_Voigt': 37...           0.0
# 3   4.442034  {'G_Reuss': 97.0, 'G_VRH': 101.0, 'G_Voigt': 1...           0.0
# 4  14.162674  {'G_Reuss': -92.0, 'G_VRH': -17.0, 'G_Voigt': ...           0.0
#
#    G_VRH  K_VRH  Elastic_Anisotropy  poisson_ratio  Y_Modulus
# 0   47.0   96.0                6.32           0.29     121.26
# 1   56.0  115.0                2.85           0.29     144.48
# 2   35.0  111.0                0.80           0.36      95.20
# 3  101.0  141.0                0.44           0.21     244.42
# 4  -17.0  130.0               -8.12           0.57     -53.38

# %%
df.drop( df[ df['Y_Modulus'] < 0 ].index , inplace=True)
df
# Out:
#      Unnamed: 0       mp_id     Formula  \
# 0             0  mp-1014229       Ti2Zn
# 1             1  mp-1014230        TiZn
# 2             2  mp-1017985        TiAg
# 3             3  mp-1018028         TiS
# 5             5  mp-1018124       Ti2Rh
# ..          ...         ...         ...
# 331         332   mp-552028  Nd2Ti2S2O5
# 332         333     mp-5999  Sm2Ti2S2O5
# 333         334     mp-6328  Na2Ti2Sb2O
# 334         335   mp-998980    TiAlFeCo
# 335         336   mp-560767     KNaTiO3
#
#                                       Composition       IPF   Density  \
# 0                          {'Ti': 2.0, 'Zn': 1.0}  0.163919  5.462442
# 1                          {'Ti': 1.0, 'Zn': 1.0}  0.174651  6.036543
# 2                          {'Ti': 1.0, 'Ag': 1.0}  0.226014  7.340359
# 3                           {'Ti': 1.0, 'S': 1.0}  0.182130  4.442034
# 5                          {'Ti': 2.0, 'Rh': 1.0}  0.148441  7.088660
# ..                                            ...       ...       ...
# 331    {'Nd': 2.0, 'Ti': 2.0, 'S': 2.0, 'O': 5.0}  0.401144  5.012983
# 332    {'Sm': 2.0, 'Ti': 2.0, 'S': 2.0, 'O': 5.0}  0.398389  5.233540
# 333   {'Na': 2.0, 'Ti': 2.0, 'Sb': 2.0, 'O': 1.0}  0.217025  4.601878
# 334  {'Ti': 1.0, 'Al': 1.0, 'Fe': 1.0, 'Co': 1.0}  0.170756  6.423142
# 335    {'K': 1.0, 'Na': 1.0, 'Ti': 1.0, 'O': 3.0}  0.551255  2.952356
#
#                                         Elastic_Tensor  E_above_Hull  G_VRH  \
# 0    {'G_Reuss': 29.0, 'G_VRH': 47.0, 'G_Voigt': 65...           0.0   47.0
# 1    {'G_Reuss': 44.0, 'G_VRH': 56.0, 'G_Voigt': 69...           0.0   56.0
# 2    {'G_Reuss': 32.0, 'G_VRH': 35.0, 'G_Voigt': 37...           0.0   35.0
# 3    {'G_Reuss': 97.0, 'G_VRH': 101.0, 'G_Voigt': 1...           0.0  101.0
# 5    {'G_Reuss': 81.0, 'G_VRH': 82.0, 'G_Voigt': 83...           0.0   82.0
# ..                                                 ...           ...    ...
# 331  {'G_Reuss': 49.0, 'G_VRH': 54.0, 'G_Voigt': 59...           0.0   54.0
# 332  {'G_Reuss': 54.0, 'G_VRH': 58.0, 'G_Voigt': 62...           0.0   58.0
# 333  {'G_Reuss': 27.0, 'G_VRH': 18.0, 'G_Voigt': 10...           0.0   18.0
# 334  {'G_Reuss': 127.0, 'G_VRH': 127.0, 'G_Voigt': ...           0.0  127.0
# 335  {'G_Reuss': 18.0, 'G_VRH': 26.0, 'G_Voigt': 33...           0.0   26.0
#
#      K_VRH  Elastic_Anisotropy  poisson_ratio  Y_Modulus
# 0     96.0                6.32           0.29     121.26
# 1    115.0                2.85           0.29     144.48
# 2    111.0                0.80           0.36      95.20
# 3    141.0                0.44           0.21     244.42
# 5    157.0                0.12           0.28     209.92
# ..     ...                 ...            ...        ...
# 331  127.0                1.00           0.31     141.48
# 332  134.0                0.77           0.31     151.96
# 333   52.0               -2.81           0.34      48.24
# 334  175.0                0.01           0.21     307.34
# 335   56.0                4.12           0.30      67.60
#
# [331 rows x 13 columns]

# %%
plt.scatter(df.Density, df.Y_Modulus)
plt.xlabel('Density')
plt.ylabel('Y_Modulus')
plt.show()

# %%
X = df.Density.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[5.46244184],
#        [6.03654254],
#        [7.34035857],
#        [4.44203401],
#        [7.08866045]])

# %%
X.shape
# Out:
# (331, 1)

# %%
y = df.Y_Modulus

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (331,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [9.82637013]
# 114.7759600642169

# %%
reg = model.fit(X, y)
reg.score(X, y)
# Out:
# 0.10824070766310767

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.10824070766310767

# %%
R2 = reg.score(X, y)

# %%
import plotly
import plotly.graph_objs as go
from plotly.offline import iplot

plotly.offline.init_notebook_mode(connected=True)
layout_test = go.Layout(title= "Ti compounds", hovermode= 'closest',
                  font = dict(family='Times New Roman',size=36),
                  xaxis= dict(title= 'Density [g/cm<sup>-3</sup>]',zeroline= False, gridwidth= 2), #To change range put command inside xaxis dictionary after gridwidth range=[-XX,XX]
                  yaxis= dict(title= "Young's Modulus [GPa]",zeroline= False, gridwidth= 2,range=[0,600]), #To change range put command inside yaxis dictionary after gridwidth range=[-YY,YY]
                  height = 800,
                  width = 800,
    showlegend= False           
)

#Scatter plot of collected data. Use df_oxide_all dataframe. df_oxide_all.Density will pull density column. Could change Density or IPF to Molar Volume or simply volume if you wanted.
trace_test = go.Scatter(x = df.Density, y = df.Y_Modulus, mode = 'markers', text = df.Formula,
                           marker=dict(size=12, color=(df['poisson_ratio']),
                               colorbar = dict(title={ 'text': "Poisson Ratio", 
                                                    'font': {'family':'Georgia', 'size': 18}},  
                                             tickfont={'family':'Georgia', 'size': 16 })), 
                        name = 'All Queries')

predictions = y_pred.reshape(1,-1).tolist()[0]
full_x_list =X.reshape(1,-1).tolist()[0]

prediction = go.Scatter(x = full_x_list, y = predictions, mode = 'lines+text', 
                            line = dict(color = "blue", width = 5),name= "Model" )

import plotly.express as px
data_test = [trace_test, prediction]
fig_test = go.Figure(data_test, layout=layout_test)
fig_test.add_annotation(
            x=15,
            y=500,
            text= f"Linear regression model:<br>Y={model.coef_[0]:,.3f}X+{model.intercept_:,.3f}<br>R<sup>2</sup> = {R2:,.3f}", 
            font=dict(
                color="blue",
                size=36
            )
            )
iplot(fig_test)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="8ebc1671-2321-4ded-8d76-afcb0dda2823" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ebc1671-2321-4ded-8d76-afcb0dda2823")) {
#                     Plotly.newPlot(
#                         '8ebc1671-2321-4ded-8d76-afcb0dda2823',
#                         [{"marker": {"color": [0.29, 0.29, 0.36, 0.21, 0.28, 0.14, 0.38, 0.26, 0.27, 0.13, 0.31, 0.27, 0.26, 0.34, 0.34, 0.38, 0.09, 0.31, 0.4, 0.33, 0.24, 0.15, 0.34, 0.28, 0.38, 0.25, 0.27, 0.21, 0.37, 0.25, 0.22, 0.28, 0.3, 0.3, 0.22, 0.38, 0.36, 0.28, 0.2, 0.32, 0.28, 0.34, 0.34, 0.26, 0.31, 0.43, 0.38, 0.3, 0.17, 0.27, 0.29, 0.39, 0.34, 0.28, 0.3, 0.2, 0.34, 0.34, 0.28, 0.22, 0.23, 0.24, 0.46, 0.35, 0.2, 0.25, 0.33, 0.3, 0.38, 0.28, 0.23, 0.28