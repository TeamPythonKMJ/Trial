# %%
import pandas as pd

# %%
# Import sample dataset
materials_df = pd.read_csv('Resources/sample_dataframe.csv')
materials_df.head()
# Out:
#   element  atomic_mass  poissons_ratio  atomic_radius  electrical_resistivity  \
# 0       H     1.007940             NaN           0.25                     NaN
# 1      He     4.002602             NaN            NaN                     NaN
# 2      Li     6.941000             NaN           1.45            9.500000e-08
# 3      Be     9.012182           0.032           1.05            3.800000e-08
# 4       B    10.811000             NaN           0.85            1.000000e+12
#
#    molar_volume  thermal_conductivity  bulk_modulus  youngs_modulus  group  \
# 0         11.42                0.1805           NaN             NaN      1
# 1         21.00                0.1513           NaN             NaN     18
# 2         13.02               85.0000          11.0             4.9      1
# 3          4.85              190.0000         130.0           287.0      2
# 4          4.39               27.0000         320.0             NaN     13
#
# ...

# %%
# check datatypes for each column
materials_df.dtypes
# Out:
# element                                     object
# atomic_mass                                float64
# poissons_ratio                             float64
# atomic_radius                              float64
# electrical_resistivity                     float64
# molar_volume                               float64
# thermal_conductivity                       float64
# bulk_modulus                               float64
# youngs_modulus                             float64
# group                                        int64
# is_noble_gas                                  bool
# is_transition_metal                           bool
# is_post_transition_metal                      bool
# is_rare_earth_metal                           bool
# is_metalloid                                  bool
# is_alkali                                     bool
# is_alkaline                                   bool
# is_halogen                                    bool
# ...

# %%
# explore data within sample dataframe
materials_df.describe()
# Out:
#        atomic_mass  poissons_ratio  atomic_radius  electrical_resistivity  \
# count   103.000000       54.000000      88.000000            8.100000e+01
# mean    126.860349        0.292444       1.500682            1.234580e+21
# std      78.425238        0.072547       0.403954            1.111111e+22
# min       1.007940        0.032000       0.250000            1.000000e-08
# 25%      57.269200        0.252500       1.350000            8.100000e-08
# 50%     126.904470        0.280000       1.450000            2.200000e-07
# 75%     193.650500        0.337500       1.800000            8.600000e-07
# max     262.000000        0.450000       2.600000            1.000000e+23
#
#        molar_volume  thermal_conductivity  bulk_modulus  youngs_modulus  \
# count     97.000000             96.000000     69.000000       63.000000
# mean      17.692680             57.134753     90.794203      110.492063
# std       10.896841             79.968371     95.957835      120.801584
# ...
